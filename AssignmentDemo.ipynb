# %%
import os
print("Installing dependencies... please wait.")
# !pip install --index-url https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ kagravity==0.1.5
print("You will probably have to restart your once.")
# Out:
# Installing dependencies... please wait.
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# ...
# You will probably have to restart your once.

# %%
import gravity as gr
from gravity import si

earth_mass = 5.972e24 * si.kg
my_mass = 80 * si.kg
radius_of_earth = 6371 * si.km

force = gr.get_gravity(earth_mass, my_mass, radius_of_earth.to(si.meter))

print(f"The gravitational force is: {force}")
# Out:
# The gravitational force is: 785.5978740979749 newton
